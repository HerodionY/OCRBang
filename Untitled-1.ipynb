# %%
# !pip install pytesseract
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB 1.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.1/2.5 MB 762.6 kB/s eta 0:00:04
#    - -------------------------------------- 0.1/2.5 MB 744.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/2.5 MB 853.3 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.5 MB 980.4 kB/s eta 0:00:03
#    --- ------------------------------------ 0.2/2.5 MB 980.4 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.5 MB 1.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.3/2.5 MB 999.9 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.4/2.5 MB 967.1 kB/s eta 0:00:03
#    ------ --------------------------------- 0.4/2.5 MB 1.0 MB/s eta 0:00:03
# ...
